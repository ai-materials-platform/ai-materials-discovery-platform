# %%
import pandas as pd
import numpy as np

df = pd.read_excel("../data/raw/STMECH_AUS_SS.xlsx", sheet_name="alldata", header=5)
df = df.replace(["Na", "NA", "na", ""], np.nan)

df.head()

# %%
df.shape

# %%
df.columns.tolist()

# %%
missing_report = pd.DataFrame({
    "missing_count": df.isna().sum(),
    "missing_pct": (df.isna().mean() * 100).round(2),
    "dtype": df.dtypes.astype(str),
}).sort_values("missing_pct", ascending=False)

missing_report.head(15)

# %%
df[["0.2%proof_stress (M Pa)", "UTS (M Pa)", "Temperature (K)"]].describe()
